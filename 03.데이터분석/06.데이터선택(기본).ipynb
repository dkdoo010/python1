# %%
import pandas as pd
df = pd.read_csv('data/score.csv')
df
# Out:
#   Unnamed: 0   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0         1번  채치수  북산고  197   90   85  100  95  85      Python
# 1         2번  정대만  북산고  184   40   35   50  55  25        Java
# 2         3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3         4번  서태웅  북산고  187   40   60   70  75  80         NaN
# 4         5번  강백호  북산고  188   15   20   10  35  10         NaN
# 5         6번  변덕규  능남고  202   80  100   95  85  80           C
# 6         7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7         8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
data = {
    '이름' : ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협'],
    '학교' : ['북산고', '북산고', '북산고', '북산고', '북산고', '능남고', '능남고', '능남고'],
    '키' : [197, 184, 168, 187, 188, 202, 188, 190],
    '국어' : [90, 40, 80, 40, 15, 80, 55, 100],
    '영어' : [85, 35, 75, 60, 20, 100, 65, 85],
    '수학' : [100, 50, 70, 70, 10, 95, 45, 90],
    '과학' : [95, 55, 80, 75, 35, 85, 40, 95],
    '사회' : [85, 25, 75, 80, 10, 80, 35, 95],
    'SW특기' : ['Python', 'Java', 'Javascript', '', '', 'C', 'PYTHON', 'C#']
}

# %%
df = pd.DataFrame(data, index=['1번', '2번', '3번', '4번','5번', '6번', '7번', '8번'])
df
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 1번  채치수  북산고  197   90   85  100  95  85      Python
# 2번  정대만  북산고  184   40   35   50  55  25        Java
# 3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번  서태웅  북산고  187   40   60   70  75  80
# 5번  강백호  북산고  188   15   20   10  35  10
# 6번  변덕규  능남고  202   80  100   95  85  80           C
# 7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df['이름']
# Out:
# 1번    채치수
# 2번    정대만
# 3번    송태섭
# 4번    서태웅
# 5번    강백호
# 6번    변덕규
# 7번    황태산
# 8번    윤대협
# Name: 이름, dtype: object

# %%
df[cols[-1]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df[cols[-1]]
#
# NameError: name 'cols' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df[:'5번']
#
# File c:\Users\AIPM\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 # Do we have a slicer (on rows)?
#    4089 if isinstance(key, slice):
# -> 4090     return self._getitem_slice(key)
#    4092 # Do we have a (boolean) DataFrame?
#    4093 if isinstance(key, DataFrame):
#
# File c:\Users\AIPM\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:4368, in NDFrame._getitem_slice(self, key)
#    4363 """
#    4364 __getitem__ for the case where the key is a slice object.
#    4365 """
#    4366 # _convert_slice_indexer to determine if this slice is positional
#    4367 #  or label based, and if the latter, convert to positional
# -> 4368 slobj = self.index._convert_slice_indexer(key, kind="getitem")
#    4369 if isinstance(slobj, np.ndarray):
#    4370     # reachable with DatetimeIndex
#    4371     indexer = lib.maybe_indices_to_slice(
#    4372         slobj.astype(np.intp, copy=False), len(self)
#    4373     )
#
# File c:\Users\AIPM\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:4256, in Index._convert_slice_indexer(self, key, kind)
#    4253 elif self.dtype.kind in "iu":
#    4254     # Note: these checks are redundant if we know is_index_slice
#    4255     self._validate_indexer("slice", key.start, "getitem")
# -> 4256     self._validate_indexer("slice", key.stop, "getitem")
#    4257     self._validate_indexer("slice", key.step, "getitem")
#    4258     return key
#
# File c:\Users\AIPM\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6752, in Index._validate_indexer(self, form, key, kind)
#    6747 """
#    6748 If we are positional indexer, validate that we have appropriate
#    6749 typed bounds must be an integer.
#    6750 """
#    6751 if not lib.is_int_or_none(key):
# -> 6752     self._raise_invalid_indexer(form, key)
#
# File c:\Users\AIPM\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:4308, in Index._raise_invalid_indexer(self, form, key, reraise)
#    4306 if reraise is not lib.no_default:
#    4307     raise TypeError(msg) from reraise
# -> 4308 raise TypeError(msg)
#
# TypeError: cannot do slice indexing on RangeIndex with these indexers [5번] of type str
