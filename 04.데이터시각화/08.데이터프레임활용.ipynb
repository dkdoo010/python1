# %%
import pandas as pd
df = pd.read_csv('data/score.csv', index_col='지원번호')
import matplotlib.pyplot as plt

plt.rc('font', family = 'Malgun Gothic')
plt.rc('font', size = 10)
plt.rc('axes', unicode_minus = False)

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80        Java
# 5번    강백호  북산고  188   15   20   10  35  10        Java
# 6번    변덕규  능남고  202   80  100   95  85  80          C#
# 7번    황태산  능남고  188   55   65   45  40  35      Python
# 8번    윤대협  능남고  190  100   85   90  95  95          C#
# 9번    홍길동  산북고  190  100   85   90  95  95          C#
# 10번   강감찬  남능고  190  100   85   90  95  95        java
# 11번   이순신  산북고  190  100   85   90  95  95      Python
# 12번   성춘향  산북고  190  100   85   90  95  95      Python
# 13번   이몽룡  남능고  190  100   85   90  95  95        Java

# %%
df.loc['3번', '학교'] = '산북고'
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  산북고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80        Java
# 5번    강백호  북산고  188   15   20   10  35  10        Java
# 6번    변덕규  능남고  202   80  100   95  85  80          C#
# 7번    황태산  능남고  188   55   65   45  40  35      Python
# 8번    윤대협  능남고  190  100   85   90  95  95          C#
# 9번    홍길동  산북고  190  100   85   90  95  95          C#
# 10번   강감찬  남능고  190  100   85   90  95  95        java
# 11번   이순신  산북고  190  100   85   90  95  95      Python
# 12번   성춘향  산북고  190  100   85   90  95  95      Python
# 13번   이몽룡  남능고  190  100   85   90  95  95        Java

# %%
df.loc['7번', '학교'] = '남능고'
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  산북고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80        Java
# 5번    강백호  북산고  188   15   20   10  35  10        Java
# 6번    변덕규  능남고  202   80  100   95  85  80          C#
# 7번    황태산  남능고  188   55   65   45  40  35      Python
# 8번    윤대협  능남고  190  100   85   90  95  95          C#
# 9번    홍길동  산북고  190  100   85   90  95  95          C#
# 10번   강감찬  남능고  190  100   85   90  95  95        java
# 11번   이순신  산북고  190  100   85   90  95  95      Python
# 12번   성춘향  산북고  190  100   85   90  95  95      Python
# 13번   이몽룡  남능고  190  100   85   90  95  95        Java

# %%
group=df.groupby('학교')['키'].mean()
group
# Out:
# 학교
# 남능고    189.333333
# 능남고    196.000000
# 북산고    189.000000
# 산북고    184.500000
# Name: 키, dtype: float64

# %%
school= group.index
height = group.values
school, height
# Out:
# (Index(['남능고', '능남고', '북산고', '산북고'], dtype='object', name='학교'),
#  array([189.33333333, 196.        , 189.        , 184.5       ]))

# %%
plt.bar(school, height)
for idx, h in enumerate(height):
    plt.text(idx, h+1, f'{h:.2f}cm', ha='center')
plt.xticks(school, [s + '등학교' for s in school], rotation=45)


plt.show()

# %%
#학교별 학생수를 막대그래프로 출력
group = df.groupby('학교').size()

school = group.index.tolist()
count = group.values.tolist()

group
# Out:
# 학교
# 남능고    3
# 능남고    2
# 북산고    4
# 산북고    4
# dtype: int64

# %%
plt.figure(figsize=(5, 3))
plt.bar(school, count)

# 막대 위에 학생 수 표시
for idx, c in enumerate(count):
    plt.text(idx, c + 0.1, f'{c}명', ha='center')

# y축 범위 및 눈금 설정
plt.ylim(0, max(count) + 1)
plt.yticks(range(0, max(count) + 2))

# 라벨 및 제목
plt.xlabel('학교')
plt.ylabel('학생 수')
plt.title('학교별 학생 수')

plt.tight_layout()
plt.show()

# %%
df['SW특기'] = df['SW특기'].str.capitalize
df.fillna({'SW특기':'없음'})
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회  \
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85
# 2번    정대만  북산고  184   40   35   50  55  25
# 3번    송태섭  산북고  168   80   75   70  80  75
# 4번    서태웅  북산고  187   40   60   70  75  80
# 5번    강백호  북산고  188   15   20   10  35  10
# 6번    변덕규  능남고  202   80  100   95  85  80
# 7번    황태산  남능고  188   55   65   45  40  35
# 8번    윤대협  능남고  190  100   85   90  95  95
# 9번    홍길동  산북고  190  100   85   90  95  95
# 10번   강감찬  남능고  190  100   85   90  95  95
# 11번   이순신  산북고  190  100   85   90  95  95
# 12번   성춘향  산북고  190  100   85   90  95  95
# 13번   이몽룡  남능고  190  100   85   90  95  95
#
#                                                    SW특기
# 지원번호
# 1번    <bound method StringMethods.capitalize of <pan...
# 2번    <bound method StringMethods.capitalize of <pan...
# 3번    <bound method StringMethods.capitalize of <pan...
# 4번    <bound method StringMethods.capitalize of <pan...
# 5번    <bound method StringMethods.capitalize of <pan...
# 6번    <bound method StringMethods.capitalize of <pan...
# 7번    <bound method StringMethods.capitalize of <pan...
# 8번    <bound method StringMethods.capitalize of <pan...
# 9번    <bound method StringMethods.capitalize of <pan...
# 10번   <bound method StringMethods.capitalize of <pan...
# 11번   <bound method StringMethods.capitalize of <pan...
# 12번   <bound method StringMethods.capitalize of <pan...
# 13번   <bound method StringMethods.capitalize of <pan...

# %%
print(type(sw), sw)
print(type(count), count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(type(sw), sw)
#       2 print(type(count), count)
#
# NameError: name 'sw' is not defined

# %%
# 학생별 평균 점수 계산
df['평균'] = df.loc[:, '국어':'사회'].mean(axis=1)

# 학교별 평균 점수 집계
group = df.groupby('학교')['평균'].mean()

# x축, y축 데이터 리스트로 변환
school = group.index.tolist()
avg_score = group.values.tolist()

# 그래프 그리기
plt.figure(figsize=(6, 4))
bars = plt.bar(school, avg_score, color='pink', edgecolor='black', lw=3)

# 막대 위에 평균 점수 표시
for idx, score in enumerate(avg_score):
    plt.text(idx, score + 0.5, f'{score:.1f}', ha='center')

# y축 설정
plt.ylim(0, 100)
plt.yticks(range(0, 101, 10))

# 라벨 및 제목
plt.xlabel('학교')
plt.ylabel('평균 점수')
plt.title('학교별 평균 점수')

plt.tight_layout()
plt.show()

# %%
#학생별 키 막대그래프
import pandas as pd
df = pd.read_csv('c:/python/04.데이터시각화/data/score.csv', index_col='지원번호')

import matplotlib.pyplot as plt

plt.rc('font', family = 'Malgun Gothic')
plt.rc('font', size = 10)
plt.rc('axes', unicode_minus = False)

# %%
name = df['이름']
height = df['키']
plt.figure(figsize=(10,3))
plt.ylim(150, 210)
plt.bar(name, height, color='pink', hatch='/', ec='red')
plt.xticks(name, rotation=45, size=8, color='g')
for idx, h in enumerate(height):
    plt.text(idx, h+1, h, ha='center', color='b', size=8)

# %%
df['평균'] = df.apply(lambda row:row['국어':'사회'].mean(), axis=1) #학생별평균점수
name = df['이름']
avg = df['평균']
plt.figure(figsize=(10, 3))
plt.ylim(0, 100)
plt.bar(name, avg, color='pink', hatch='/', ec='yellow')
plt.xticks(name, rotation=45, size=8, color='g')
for idx, h in enumerate(avg):
    plt.text(idx, h+1, f'{h:.2f}', ha='center', color='g', size=8)

# %%
#4.학교별 평균점수
df['평균'] = df.apply(lambda row:row['국어':'사회'].mean(), axis=1)
group = df.groupby('학교')['평균'].mean()
labels = group.index
values = group.values
plt.figure(figsize=(10, 5))
plt.ylim(0, 100)
plt.bar(labels, values, color='pink', hatch='/', ec='yellow', width=0.5)
plt.xticks(labels, rotation=45, size=8, color='g')
for idx, value in enumerate(values):
    plt.text(idx, value+1, f'{value:.2f}점', ha='center', color='g', size=8)

# %%
#3. 학교별 평균키
group = df.groupby('학교')['키'].mean()
labels = group.index
values = group.values
plt.figure(figsize=(10, 5))
plt.ylim(160, 200)
plt.bar(labels, values, color='pink', hatch='/', ec='yellow', width=0.5)
plt.xticks(labels, rotation=45, size=8, color='g')
for idx, value in enumerate(values):
    plt.text(idx, value+1, f'{value:.2f}cm', ha='center', color='g', size=8)

# %%
#5.SW특기별인원수
df['SW특기'] = df['SW특기'].str.capitalize()
group = df.groupby('SW특기').size()
labels = group.index
values = group.values
plt.figure(figsize=(10, 5))
plt.ylim(0, 6)
plt.bar(labels, values, color='pink', hatch='/', ec='yellow', width=0.5)
plt.xticks(labels, rotation=45, size=10, color='g')
for idx, value in enumerate(values):
    plt.text(idx, value+0.03, f'{value}명', ha='center', color='g', size=10)

# %%
#학생별(이름) 평균점수
enroll = pd.read_csv('data/수강.csv')
group= enroll.groupby('학생번호')['점수'].mean().to_frame()
stu= pd.read_csv('data/학생.csv')
merge = stu.merge(group, how='left', on='학생번호')
merge.fillna({'점수':0}, inplace=True)
merge
# Out:
#        학생번호 학생이름 학생학과  학년      생년월일  지도교수         점수
# 0  92414029  서연우   전산   3  73/10/06   228  81.250000
# 1  92414033  김창덕   전산   4  73/10/26   221  82.500000
# 2  92514009  이지행   전자   4  73/11/16   311  77.500000
# 3  92514023  김형명   전자   4  73/08/29   311  70.000000
# 4  92454018  이원구   건축   3  74/09/30   509  90.000000
# 5  95454003  이재영   건축   4  76/02/06   509  81.000000
# 6  95414058  박혜경   전산   4  76/03/12   221  83.333333
# 7  96414404  김수정   전산   3  77/12/22   228  75.000000
# 8  96255452  황황황   전산   2  78/12/54   229   0.000000

# %%
plt.bar(merge['학생이름'], merge['점수'])
plt.ylim(0, 100)
plt.xticks(merge['학생이름'], rotation=90)
for idx, grade in enumerate(merge['점수']):
    plt.text(idx, grade+1, f'{grade:.2f}', ha='center')

# %%
cou = pd.read_csv('data/강좌.csv')
enroll = pd.read_csv('data/수강.csv')
group = enroll.groupby('강좌번호')['점수'].mean().to_frame()
merge = cou.merge(group, how='left', on='강좌번호')
merge.fillna({'점수': 0}, inplace=True)
merge
# Out:
#    강좌번호     강좌이름  강의시수  강의실  담당교수  최대인원         점수
# 0  C301    파일처리론     3  506   221   100  76.333333
# 1  C401   데이터베이스     3  414   221    80  85.000000
# 2  C421     알고리즘     3  510   228    80  75.000000
# 3  C312     자료구조     2  510   228   100  80.000000
# 4  E221     논리회로     3  304   311   100  81.250000
# 5  A109  한국의건축문화     2  101   509   120  87.500000
# 6  A108    건축학개론     2  101   509   120   0.000000

# %%
#강좌별(이름) 평균 막대그래프
nos = merge['학생번호']
name = merge('data/수강.csv')
grades = merge['점수']
plt.figure(figsize=(10, 3))

# %%
nos = merge['강좌번호']
names = merge['강좌이름']
grades = merge['점수']
plt.figure(figsize=(10, 3))
plt.bar(names, grades)

xticks = [f'{names[idx]}({nos[idx]})' for idx in range(len(nos))]
plt.xticks(names, xticks, rotation=45)

yticks = [y for y in range(0, 101, 20)]
plt.yticks(yticks, [f'{y}점' for y in yticks])

plt.ylim(0, 100)
for idx in range(len(nos)):
    plt.text(idx, grades[idx]+1, f'{grades[idx]:.1f}', ha='center')
plt.show()
