# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

# %%
#선형회귀(최소제곱법)
from sklearn.linear_model import LinearRegression

# %%
dataset = pd.read_csv('data/LinearRegressionData.csv')
dataset.head()
# Out:
#    hour  score
# 0   0.5     10
# 1   1.2      8
# 2   1.8     14
# 3   2.4     26
# 4   2.6     22

# %%
#독립변수
X = dataset.iloc[:, :-1].values
X.shape
# Out:
# (25, 1)

# %%
#종속변수
y = dataset.iloc[:, -1].values
y.shape
# Out:
# (25,)

# %%
reg = LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
#9시간 공부했을때 점수?
pred=reg.predict([[9]])
print(pred[0], pred.shape)
# Out:
# 74.20581818181819 (1,)

# %%
#8, 7, 5시간 공부했을때 점수?
pred=reg.predict([[8], [7], [5]])
print(pred[0], pred[1], pred[2], pred.shape)
# Out:
# 70.23422161917685 66.26262505653551 58.31943193125283 (3,)

# %%
import math
import numpy as np
max =math.ceil(X.max())
xticks = [x for x in np.arange(0, max+1, 0.5)]
print(xticks)
# Out:
# [np.float64(0.0), np.float64(0.5), np.float64(1.0), np.float64(1.5), np.float64(2.0), np.float64(2.5), np.float64(3.0), np.float64(3.5), np.float64(4.0), np.float64(4.5), np.float64(5.0), np.float64(5.5), np.float64(6.0), np.float64(6.5), np.float64(7.0), np.float64(7.5), np.float64(8.0), np.float64(8.5), np.float64(9.0), np.float64(9.5), np.float64(10.0), np.float64(10.5), np.float64(11.0), np.float64(11.5)]

# %%
#실제점수와 예측점수를 시각화
plt.figure(figsize=(10,5))
plt.scatter(X, y, label='실제점수')
plt.plot(X, reg.predict(X), color='g', label='예측점수')
plt.grid(True, ls='--', lw=0.5)
plt.xticks(xticks, [f'{x}h' for x in xticks], size=8, rotation=45)
plt.legend()
plt.show()

# %%
#y=mx + b
m=reg.coef_
b=reg.intercept_
y=m * 9 + b
y
# Out:
# array([74.20581818])

# %%
reg.predict([[9]])
# Out:
# array([74.20581818])

# %%
X.shape, y.shape
# Out:
# ((25, 1), (1,))

# %%
import pandas as pd

df = pd.read_csv('LinearRegressionData.csv')

# 숫자형으로 변환
df['hour'] = pd.to_numeric(df['hour'], errors='coerce')
df['score'] = pd.to_numeric(df['score'], errors='coerce')

# 결측값 제거
df = df.dropna()

# X, y 분리
X = df[['hour']]  # 2차원 DataFrame
y = df['score']   # 1차원 Series
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[94], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv('LinearRegressionData.csv')
#       5 # 숫자형으로 변환
#       6 df['hour'] = pd.to_numeric(df['hour'], errors='coerce')
#
# ...

# %%
sr = SGDRegressor()
sr.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 2
#       1 sr = SGDRegressor()
# ----> 2 sr.fit(X, y)
#
# File c:\Users\AIPM\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\AIPM\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1618, in BaseSGDRegressor.fit(self, X, y, coef_init, intercept_init, sample_weight)
#    1592 """Fit linear model with Stochastic Gradient Descent.
#    1593
#    1594 Parameters
# ...

# %%
plt.figure(figsize=(10, 5))
plt.scatter(X, y)
plt.plot(X, sr.predict(X), color='g')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 2
#       1 plt.figure(figsize=(10, 5))
# ----> 2 plt.scatter(X, y)
#       3 plt.plot(X, sr.predict(X), color='g')
#       4 plt.show()
#
# File c:\Users\AIPM\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %%
sr = SGDRegressor(max_iter=100, eta0=0.0001, random_state==0. verbose=1)
sr.fit(X, y)
# Out:
#   Cell In[46], line 1
#     sr = SGDRegressor(max_iter=100, eta0=0.0001, random_state==0. verbose=1)
#                                                  ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
def model_sgd(iter, eta0):
    sr = SGDRegressor(max_iter= eta0=eta0, random_state=0)
    sr.fit(X, y)
# Out:
#   Cell In[47], line 2
#     sr = SGDRegressor(max_iter= eta0=eta0, random_state=0)
#                                     ^
# SyntaxError: invalid syntax

# %%
import time
for i in raange(100, 1000, 100):
    model_sgd(i, 0.0001)
    time.sleep(3)
    plt.figure(figsize=(10, 5))
    plt.scatter(X, y)
    plt.plot(X, sr.predict(X), color='g')
    plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2)

# %%
x_train.shape, X_test.shape, X.shape

# %%
sr = SGDRegressor()
sr.fit(X_train, y_test)
